# %% [markdown]
# # Full Example
# THe idea with this NB is to do the same as the pymc_prophet_example NB but do everything (holidays, regressors etc...) in a single example and compare pymc_prohet with prophet. Then we will use this to build the Bayesian PyMC component.

# %%
from pymc_prophet.model import ProphetModel, BayesTSConfig

import datetime as dt
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
import pymc as pm

print(f"Running on PyMC v{pm.__version__}")

# Initialize random number generator
RANDOM_SEED = 8927
rng = np.random.default_rng(RANDOM_SEED)
az.style.use("arviz-darkgrid")
# Out:
# Running on PyMC v5.23.0

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df['ds'] = pd.to_datetime(df['ds'])

# %% [markdown]
# ## Holidays
# These are user defined. We will also add auto US ones.

# %%
np.random.default_rng(RANDOM_SEED)
# Out:
# Generator(PCG64) at 0x144936C00

# %%
playoffs = pd.DataFrame({
  'holiday': 'playoff',
  'ds': pd.to_datetime(['2008-01-13', '2009-01-03', '2010-01-16',
                        '2010-01-24', '2010-02-07', '2011-01-08',
                        '2013-01-12', '2014-01-12', '2014-01-19',
                        '2014-02-02', '2015-01-11', '2016-01-17',
                        '2016-01-24', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
superbowls = pd.DataFrame({
  'holiday': 'superbowl',
  'ds': pd.to_datetime(['2010-02-07', '2014-02-02', '2016-02-07']),
  'lower_window': 0,
  'upper_window': 1,
})
holidays = pd.concat((playoffs, superbowls))

# %% [markdown]
# ## Regressor
# Custom dataset for Sundays during the NFL Season.

# %%
def nfl_sunday(ds):
    date = pd.to_datetime(ds)
    if date.weekday() == 6 and (date.month > 8 or date.month < 2):
        return 1
    else:
        return 0

df['nfl_sunday'] = df['ds'].apply(nfl_sunday)

# %% [markdown]
# ## Modelling

# %%
train_df = df.query("ds.dt.year <= 2014")
test_df = df.query("ds.dt.year > 2014")

# %% [markdown]
# ### PyMC

# %%
ts_config = BayesTSConfig()
ts_model = ProphetModel(ts_config)
ts_model.add_holiday_country("US")
ts_model.add_holiday(holidays)
ts_model.add_regressor("nfl_sunday", mode="additive")

# ts_model.assign_model_matrix(train_df)

# %%
ts_model.fit(train_df, random_seed=rng)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [k, m, beta_additive, sigma_obs]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ts_model.fit(train_df, random_seed=rng)
#
# File ~/pymc_prophet/src/pymc_prophet/model.py:211, in BayesTS.fit(self, raw_df, **kwargs)
#     207 """
#     208 Fit the model to the raw dataframe
#     209 """
#     210 self.assign_model_matrix(raw_df)
# --> 211 self._fit(raw_df, **kwargs)
#
# File ~/pymc_prophet/src/pymc_prophet/model.py:646, in ProphetModel._fit(self, raw_df, **kwargs)
#     642 sample_args.update(kwargs)
#     644 with self.forecast_model:
#     645     # sample posterior variables and deterministics, observed is not sampled
# --> 646     self.posterior: InferenceData = pm.sample(**sample_args)
#     647     # sample posterior predictive y_obs
#     648     self.in_sample_predictive: InferenceData = pm.sample_posterior_predictive(self.posterior)
#
# File ~/pymc_prophet/.venv/lib/python3.12/site-packages/pymc/sampling/mcmc.py:935, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, compile_kwargs, **kwargs)
#     933 _print_step_hierarchy(step)
#     934 try:
# --> 935     _mp_sample(**sample_args, **parallel_args)
#     936 except pickle.PickleError:
#     937     _log.warning("Could not pickle model, sampling singlethreaded.")
#
# File ~/pymc_prophet/.venv/lib/python3.12/site-packages/pymc/sampling/mcmc.py:1411, in _mp_sample(draws, tune, step, chains, cores, rngs, start, progressbar, progressbar_theme, traces, model, callback, blas_cores, mp_ctx, **kwargs)
#    1409 try:
#    1410     with sampler:
# -> 1411         for draw in sampler:
#    1412             strace = traces[draw.chain]
#    1413             if not zarr_recording:
#    1414                 # Zarr recording happens in each process
#
# File ~/pymc_prophet/.venv/lib/python3.12/site-packages/pymc/sampling/parallel.py:510, in ParallelSampler.__iter__(self)
#     508 with self._progress:
#     509     while self._active:
# --> 510         draw = ProcessAdapter.recv_draw(self._active)
#     511         proc, is_last, draw, tuning, stats = draw
#     513         self._progress.update(
#     514             chain_idx=proc.chain, is_last=is_last, draw=draw, tuning=tuning, stats=stats
#     515         )
#
# File ~/pymc_prophet/.venv/lib/python3.12/site-packages/pymc/sampling/parallel.py:371, in ProcessAdapter.recv_draw(processes, timeout)
#     369 idxs = {id(proc._msg_pipe): proc for proc in processes}
#     370 proc = idxs[id(ready[0])]
# --> 371 msg = ready[0].recv()
#     373 if msg[0] == "error":
#     374     old_error = msg[1]
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/multiprocessing/connection.py:250, in _ConnectionBase.recv(self)
#     248 self._check_closed()
#     249 self._check_readable()
# --> 250 buf = self._recv_bytes()
#     251 return _ForkingPickler.loads(buf.getbuffer())
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/multiprocessing/connection.py:430, in Connection._recv_bytes(self, maxsize)
#     429 def _recv_bytes(self, maxsize=None):
# --> 430     buf = self._recv(4)
#     431     size, = struct.unpack("!i", buf.getvalue())
#     432     if size == -1:
#
# File ~/.local/share/uv/python/cpython-3.12.10-macos-aarch64-none/lib/python3.12/multiprocessing/connection.py:399, in Connection._recv(self, size, read)
#     397 if n == 0:
#     398     if remaining == size:
# --> 399         raise EOFError
#     400     else:
#     401         raise OSError("got end of file during message")
#
# EOFError:

# %%
ts_model.predict(test_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ts_model.predict(test_df)
#
# File ~/pymc_prophet/src/pymc_prophet/model.py:565, in ProphetModel.predict(self, future_df)
#     562     coords["multiplicative_features"] = list(self.multiplicative_feature_dict.keys())
#     564 pm.set_data(new_data, coords=coords)
# --> 565 out_sample_predictive = pm.sample_posterior_predictive(self.posterior, predictions=True)
#     567 return out_sample_predictive
#
# AttributeError: 'ProphetModel' object has no attribute 'posterior'

# %%
type(ts_model.posterior)
# Out:
# arviz.data.inference_data.InferenceData

# %%
ts_model.plot()

# %%
pm.model_to_graphviz(ts_model.forecast_model)

# %% [markdown]
# #### Plot

# %%
alpha = 0.05

# posterior_idata.posterior["y_pred"]
posterior_array = posterior_predictive_idata.posterior_predictive["y_obs"]
region_color = "mediumblue"


fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x=posterior_idata.constant_data["time"],
        y=posterior_array.quantile(q=1 - alpha / 2, dim=("chain", "draw")),
        fill=None,
        mode="lines",
        line=dict(width=0, color=region_color),
        name=f"{100 - 50 * alpha} percent",
    )
)

fig.add_trace(
    go.Scatter(
        x=posterior_idata.constant_data["time"],
        y=posterior_array.quantile(q=alpha / 2, dim=("chain", "draw")),
        fill="tonexty",  # fill area between trace0 and trace1
        mode="lines",
        line=dict(width=0, color=region_color),
        name=f"{50 * alpha} percent",
    )
)

fig.add_trace(
    go.Scatter(
        x=posterior_idata.constant_data["time"],
        y=posterior_array.mean(("chain", "draw")),
        name="y_pred_mean",
        mode="lines",
        line=dict(width=1, color=region_color),
    )
)

fig.add_trace(
    go.Scatter(
        x=posterior_idata.constant_data["time"],
        y=posterior_idata.observed_data["y_obs"],
        mode="markers",
        marker=dict(color="red", size=4, opacity=0.6),
        name="y actual",
    )
)


fig.show()

# %% [markdown]
# ### Prophet

# %%
prophet_model = Prophet(holidays=holidays)
prophet_model.add_country_holidays(country_name='US')
prophet_model.add_regressor('nfl_sunday')

# %%
transformed = prophet_model.preprocess(train_df)

# %%
prophet_model = Prophet(holidays=holidays)
prophet_model.add_country_holidays(country_name='US')
prophet_model.add_regressor('nfl_sunday')
prophet_model.fit(train_df)
# Out:
# 12:43:43 - cmdstanpy - INFO - Chain [1] start processing
# 12:43:43 - cmdstanpy - INFO - Chain [1] done processing

# %%
test_df['y']
# Out:
# 2522     7.846590
# 2523     8.302018
# 2524     8.436200
# 2525     8.934587
# 2526     8.888619
#           ...
# 2900     7.817223
# 2901     9.273878
# 2902    10.333775
# 2903     9.125871
# 2904     8.891374
# Name: y, Length: 383, dtype: float64

# %%
forecast = prophet_model.predict(test_df)
fig = prophet_model.plot_components(forecast)
# Out:
# /home/jake/miniforge3/envs/pymc_env/lib/python3.12/site-packages/prophet/plot.py:196: UserWarning:
#
# The figure layout has changed to tight
